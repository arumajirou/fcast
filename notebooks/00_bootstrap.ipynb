# %% [markdown]
# # 00 Bootstrap
# 環境確認とディレクトリ初期化。

# %%
import sys, os
print(sys.version)
print("cwd:", os.getcwd())
# Out:
# 3.14.2 | packaged by conda-forge | (main, Jan 26 2026, 19:49:55) [MSC v.1944 64 bit (AMD64)]
# cwd: c:\fcast\notebooks

# %%
from fcast.config import settings
print(settings)
# Out:
# meta_url='sqlite:///./forecast_meta.db' lake_dir='./forecast_lake' reports_dir='./reports' log_level='INFO'

# %%
from pathlib import Path
from fcast.lake.paths import ensure_dirs
ensure_dirs()
Path(settings.reports_dir).mkdir(parents=True, exist_ok=True)
Path(settings.reports_dir, "pytest").mkdir(parents=True, exist_ok=True)
print("lake:", Path(settings.lake_dir).resolve())
print("reports:", Path(settings.reports_dir).resolve())
# Out:
# lake: C:\fcast\notebooks\forecast_lake
# reports: C:\fcast\notebooks\reports
